# %% [markdown]
# # Combined Partial Data (SVM)

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
  
N = 6
ind = np.arange(N) 
width = 0.18
  
full_com = [0.7652, 0.7797, 0.8431, 0.6772, 0.88, 0.47]
full_com_errors = [0.0259, 0.0239, 0.0171, 0.0359, 0.00, 0.00]
com_bar1 = plt.bar(ind, full_com, width, color = 'b', yerr = full_com_errors)

partial_com = [0.8105, 0.8639, 0.8732, 0.7330, 0.91, 0.59]
partial_com_errors = [0.0336, 0.0136, 0.0237, 0.0352, 0.00, 0.00]
com_bar2 = plt.bar(ind+width, partial_com, width, color = 'r', yerr = partial_com_errors)

plt.xlabel("Methods")
plt.ylabel('5-Fold Cross-Validation Scores')
plt.ylim(0.0, 1.15)
plt.yticks(np.arange(0.0, 1.01, step=0.10))
plt.title("Performance of SVM on Combined Data Modality (full vs partial)")
  
plt.xticks(ind+width*0.5,['ACC', 'AUC', 'F1', 'BACC', 'Sensitivity', 'Specificity'])
plt.legend( (com_bar1, com_bar2), ('Full Dataset', 'Top 1000 SNPs and 700 Gene Expressions'), loc="best" )
plt.show()

# %% [markdown]
# # Cross Validation on Genotype Data

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
# Genotype MOGONET
# ACC = 0.7286 +/- 0.0207
# F1 = 0.8212 +/- 0.0188
# AUC = 0.7208 +/- 0.0164
# BAS = 0.6282 +/- 0.0206
  
N = 9
ind = np.arange(N) 
width = 0.18
  
geno_acc = [0.7064, 0.7576, 0.7520, 0.7652, 0.7690, 0.7916, 0.7330, 0.0000, 0.7042]
geno_acc_errors = [0.0395, 0.0361, 0.0306, 0.0278, 0.0282, 0.0385, 0.0210, 0.0000, 0.0176]
geno_bar1 = plt.bar(ind, geno_acc, width, color = 'b', yerr = geno_acc_errors)

geno_auc = [0.6531, 0.7677, 0.7604, 0.7901, 0.7657, 0.8207, 0.7424, 0.8176, 0.7290]
geno_auc_errors = [0.0443, 0.0510, 0.0403, 0.0363, 0.0356, 0.0248, 0.0395, 0.0355, 0.0121]
geno_bar2 = plt.bar(ind+width, geno_auc, width, color = 'r', yerr = geno_auc_errors)

geno_f1 = [0.8200, 0.8307, 0.8381, 0.8380, 0.8511, 0.8606, 0.8302, 0.0000, 0.7956]
geno_f1_errors = [0.0270, 0.0275, 0.0195, 0.0229, 0.0192, 0.0245, 0.0147, 0.0000, 0.0178]
geno_bar3 = plt.bar(ind+width*2, geno_f1, width, color = 'y', yerr = geno_f1_errors)

geno_bas = [0.5316, 0.7000, 0.6418, 0.6993, 0.6517, 0.7118, 0.5965, 0.7674, 0.6235]
geno_bas_errors = [0.0368, 0.0352, 0.0465, 0.0257, 0.0340, 0.0600, 0.0339, 0.0256, 0.0163]
geno_bar4 = plt.bar(ind+width*3, geno_bas, width, color = 'g', yerr = geno_bas_errors)

plt.xlabel("Methods")
plt.ylabel('5-Fold Cross-Validation Scores')
plt.ylim(0.4, 1.15)
plt.yticks(np.arange(0.4, 1.01, step=0.05))
plt.title("Benchmarking ML Methods on Alzheimer's Data (Genotype)")
  
plt.xticks(ind+width*1.5,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'NN', 'RF', 'GAMI', 'MOGO'])
plt.legend( (geno_bar1, geno_bar2, geno_bar3, geno_bar4), ('Accuracy',
                                                           'AUC Score',
                                                           'F1 Score',
                                                           'Balanced Accuracy'),
           loc="best" )
plt.show()

# %% [markdown]
# # Cross Validation on CCI Data

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
# CCI MOGONET
# ACC = 0.7653 +/- 0.0140
# F1 = 0.8594 +/- 0.0086
# AUC = 0.6985 +/- 0.0160
# BAS = 0.5710 +/- 0.0216
  
N = 9
ind = np.arange(N) 
width = 0.18
  
cci_acc = [0.7026, 0.7840, 0.7443, 0.7669, 0.7632, 0.7575, 0.7347, 0.0000, 0.7125]
cci_acc_errors = [0.0312, 0.0209, 0.0375, 0.0435, 0.0326, 0.0346, 0.0421, 0.0000, 0.0252]
cci_bar1 = plt.bar(ind, cci_acc, width, color = 'b', yerr = cci_acc_errors)

cci_auc = [0.6261, 0.7701, 0.7183, 0.7383, 0.7169, 0.7679, 0.6881, 0.8205, 0.6643]
cci_auc_errors = [0.0582, 0.0421, 0.0296, 0.0894, 0.0458, 0.0284, 0.0759, 0.0386, 0.0080]
cci_bar2 = plt.bar(ind+width, cci_auc, width, color = 'r', yerr = cci_auc_errors)

cci_f1 = [0.8164, 0.8599, 0.8297, 0.8443, 0.8524, 0.8360, 0.8344, 0.0000, 0.8110]
cci_f1_errors = [0.0221, 0.0135, 0.0255, 0.0266, 0.0196, 0.0250, 0.0265, 0.0000, 0.0291]
cci_bar3 = plt.bar(ind+width*2, cci_f1, width, color = 'y', yerr = cci_f1_errors)

cci_bas = [0.5329, 0.6762, 0.6485, 0.6804, 0.6175, 0.6758, 0.5835, 0.7240, 0.5964]
cci_bas_errors = [0.0242, 0.0321, 0.0454, 0.0682, 0.0492, 0.0389, 0.0512, 0.0504, 0.0194]
cci_bar4 = plt.bar(ind+width*3, cci_bas, width, color = 'g', yerr = cci_bas_errors)

plt.xlabel("Methods")
plt.ylabel('Cross-Validation Scores')
plt.ylim(0.4, 1.15)
plt.yticks(np.arange(0.4, 1.01, step=0.05))
plt.title("Benchmarking ML Methods on Alzheimer's Data (CCI)")
  
plt.xticks(ind+width*1.5,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'NN', 'RF', 'GAMI', 'MOGO'])
plt.legend( (cci_bar1, cci_bar2, cci_bar3, cci_bar4), ('Accuracy',
                                                       'AUC Score',
                                                       'F1 Score',
                                                       'Balanced Accuracy'),
           loc="best" )
plt.show()

# %% [markdown]
# # Cross Validation on Combined Data

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/
# MOGONet results are from epoch 1850
import numpy as np
import matplotlib.pyplot as plt
  
N = 9
ind = np.arange(N) 
width = 0.18
  
com_acc = [0.7178, 0.7538, 0.7652, 0.7860, 0.7859, 0.7425, 0.7576, 0.0000, 0.7149]
com_acc_errors = [0.0321, 0.0233, 0.0259, 0.0325, 0.0279, 0.0280, 0.0282, 0.0000, 0.0156]
com_bar1 = plt.bar(ind, com_acc, width, color = 'b', yerr = com_acc_errors)

com_auc = [0.6509, 0.7309, 0.7787, 0.7979, 0.7897, 0.7740, 0.7496, 0.8180, 0.6769]
com_auc_errors = [0.0297, 0.0584, 0.0239, 0.0514, 0.0292, 0.0603, 0.0332, 0.0351, 0.0986]
com_bar2 = plt.bar(ind+width, com_auc, width, color = 'r', yerr = com_auc_errors)

com_f1 = [0.8267, 0.8326, 0.8431, 0.8518, 0.8620, 0.8194, 0.8484, 0.0000, 0.8148]
com_f1_errors = [0.0215, 0.0180, 0.0171, 0.0247, 0.0179, 0.0236, 0.0172, 0.0000, 0.0096]
com_bar3 = plt.bar(ind+width*2, com_f1, width, color = 'y', yerr = com_f1_errors)

com_bas = [0.5476, 0.6752, 0.6772, 0.7279, 0.6735, 0.6835, 0.6136, 0.7758, 0.5941]
com_bas_errors = [0.0331, 0.0243, 0.0359, 0.0410, 0.0350, 0.0481, 0.0379, 0.0336, 0.0475]
com_bar4 = plt.bar(ind+width*3, com_bas, width, color = 'g', yerr = com_bas_errors)

plt.xlabel("Methods")
plt.ylabel('5-Fold Cross-Validation Scores')
plt.ylim(0.4, 1.15)
plt.yticks(np.arange(0.4, 1.01, step=0.05))
plt.title("Benchmarking ML Methods on Alzheimer's Data (Combined)")
  
plt.xticks(ind+width*1.5,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'NN', 'RF', 'GAMI', 'MOGO'])
plt.legend( (com_bar1, com_bar2, com_bar3, com_bar4), ('Accuracy',
                                                       'AUC Score',
                                                       'F1 Score',
                                                       'Balanced Accuracy'),
           loc="best" )
plt.show()

# %% [markdown]
# # Displaying the Data A Different Way

# %% [markdown]
# ### BACC Scores

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
  
N = 9
ind = np.arange(N) 
width = 0.23

geno_bas = [0.5316, 0.7000, 0.6418, 0.6993, 0.6517, 0.7118, 0.5965, 0.7674, 0.6235]
geno_bas_errors = [0.0368, 0.0352, 0.0465, 0.0257, 0.0340, 0.0600, 0.0339, 0.0256, 0.0163]
geno_bas_bar = plt.bar(ind, geno_bas, width, color = 'b', yerr = geno_bas_errors)

cci_bas = [0.5329, 0.6762, 0.6485, 0.6804, 0.6175, 0.6758, 0.5835, 0.7240, 0.5964]
cci_bas_errors = [0.0242, 0.0321, 0.0454, 0.0682, 0.0492, 0.0389, 0.0512, 0.0504, 0.0164]
cci_bas_bar = plt.bar(ind+width, cci_bas, width, color = 'y', yerr = cci_bas_errors)

com_bas = [0.5476, 0.6752, 0.6772, 0.7279, 0.6735, 0.6835, 0.6136, 0.7758, 0.5941]
com_bas_errors = [0.0331, 0.0243, 0.0359, 0.0410, 0.0350, 0.0481, 0.0379, 0.0366, 0.0475]
com_bas_bar = plt.bar(ind+width*2, com_bas, width, color = 'r', yerr = com_bas_errors)

plt.xlabel("Methods")
plt.ylabel('Balanced Accuracy Scores')
plt.ylim(0.4, 1.15)
plt.yticks(np.arange(0.4, 1.01, step=0.05))
plt.title("BACC Scores on Alzheimer's Data Modalities")
  
plt.xticks(ind+width,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'NN', 'RF', 'GAMI', 'MOGO'])
plt.legend( (geno_bas_bar, cci_bas_bar, com_bas_bar), ('Genotype',
                                                       'Gene Expression',
                                                       'Combined'),
           loc="best" )
plt.show()

# %% [markdown]
# ### AUC Scores

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
  
N = 9
ind = np.arange(N) 
width = 0.23

geno_auc = [0.6531, 0.7677, 0.7604, 0.7901, 0.7657, 0.8207, 0.7424, 0.8176, 0.7290]
geno_auc_errors = [0.0443, 0.0510, 0.0403, 0.0363, 0.0356, 0.0248, 0.0395, 0.0355, 0.0121]
geno_auc_bar = plt.bar(ind, geno_auc, width, color = 'b', yerr = geno_auc_errors)

cci_auc = [0.6261, 0.7701, 0.7183, 0.7383, 0.7169, 0.7679, 0.6881, 0.8205, 0.6643]
cci_auc_errors = [0.0582, 0.0421, 0.0296, 0.0894, 0.0458, 0.0284, 0.0759, 0.0386, 0.0080]
cci_auc_bar = plt.bar(ind+width, cci_auc, width, color = 'y', yerr = cci_auc_errors)

com_auc = [0.6509, 0.7309, 0.7797, 0.7979, 0.7897, 0.7740, 0.7496, 0.8180, 0.6769]
com_auc_errors = [0.0297, 0.0584, 0.0239, 0.0514, 0.0292, 0.0603, 0.0332, 0.0351, 0.0986]
com_auc_bar = plt.bar(ind+width*2, com_auc, width, color = 'r', yerr = com_auc_errors)

plt.xlabel("Methods")
plt.ylabel('Area Under the Curve')
plt.ylim(0.4, 1.15)
plt.yticks(np.arange(0.4, 1.01, step=0.05))
plt.title("AUC Scores on Alzheimer's Data Modalities")
  
plt.xticks(ind+width,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'NN', 'RF', 'GAMI', 'MOGO'])
plt.legend( (geno_auc_bar, cci_auc_bar, com_auc_bar), ('Genotype',
                                                       'Gene Expression',
                                                       'Combined'),
           loc="best" )
plt.show()

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
  
N = 6
ind = np.arange(N) 
width = 0.5
  
combined = [0.7437, 0.8062, 0.7625, 0.8094, 0.7562, 0.8437]
errors3 = [0.0290, 0.0187, 0.0488, 0.0319, 0.0159, 0.0383]
bar3 = plt.bar(ind, combined, width, color = 'b', yerr = errors)

  
plt.xlabel("Methods")
plt.ylabel('Cross-Validation Accuracy')
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Benchmarking 6 ML Methods on Combined Data")
  
plt.xticks(ind,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'MLP'])
plt.show()

# %%
N = 6
ind = np.arange(N) 
width = 0.25
  
genotype2 = [0.7406, 0.8062, 0.8000, 0.8156, 0.8219, 0.8344]
errors_4 = [0.0254, 0.0272, 0.0334, 0.0388, 0.0351, 0.0403]
bar4 = plt.bar(ind, genotype2, width, color = 'r', yerr = errors_4)
  
cci2 = [0.7219, 0.7469, 0.6094, 0.7187, 0.7344, 0.7437]
errors_5 = [0.0478, 0.0207, 0.0261, 0.0383, 0.0328, 0.0125]
bar5 = plt.bar(ind+width, cci2, width, color='g', yerr = errors_5)
  
combined2 = [0.7437, 0.8062, 0.7625, 0.8094, 0.7562, 0.8437]
errors_6 = [0.0290, 0.0187, 0.0488, 0.0319, 0.0159, 0.0383]
bar6 = plt.bar(ind+width*2, combined2, width, color = 'b', yerr = errors_6)
  
plt.xlabel("Methods")
plt.ylabel('Cross-Validation Score')
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Benchmarking 6 ML Methods on Alzheimer's Data (with PCA)")
  
plt.xticks(ind+width,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'MLP'])
plt.legend( (bar4, bar5, bar6), ('Genotype Data', 'CCI Data', 'Combined Data'), loc="best" )
plt.show()

# %%
# https://www.geeksforgeeks.org/bar-plot-in-matplotlib/

import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'kNN':0.846, 'LogReg':0.878, 'SVM':0.837,
        'SGD':0.889, 'XGB':0.868, 'MLP':0.876}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='chartreuse',
        width = 0.4)
 
plt.xlabel("Method")
plt.ylabel("F1 score")
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Predictive Performance of 6 ML Methods on Genotype Data")
plt.show()

# %%
# https://www.geeksforgeeks.org/bar-plot-in-matplotlib/

import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'kNN':0.883, 'LogReg':0.873, 'SVM':0.792,
        'SGD':0.870, 'XGB':0.830, 'MLP':0.875}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='aqua',
        width = 0.4)
 
plt.xlabel("Method")
plt.ylabel("F1 score")
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Predictive Performance of 6 ML Methods on CCI Data")
plt.show()

# %%
# https://www.geeksforgeeks.org/bar-plot-in-matplotlib/

import numpy as np
import matplotlib.pyplot as plt

# creating the dataset
data = {'kNN':0.883, 'LogReg':0.873, 'SVM':0.792,
        'SGD':0.870, 'XGB':0.830, 'MLP':0.875}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='magenta',
        width = 0.4)
 
plt.xlabel("Method")
plt.ylabel("F1 score")
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Predictive Performance of 6 ML Methods on CCI Data")
plt.show()

# %%
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

import numpy as np
import matplotlib.pyplot as plt
  
N = 6
ind = np.arange(N) 
width = 0.25
  
f1 = [0.838, 0.878, 0.881, 0.860, 0.865, 0.873]
bar1 = plt.bar(ind, f1, width, color = 'violet')
  
bas = [0.580, 0.738, 0.775, 0.691, 0.687, 0.727]
bar2 = plt.bar(ind+width, bas, width, color='orange')
  
plt.xlabel("Methods")
plt.ylabel('Objective Metric')
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Predictive Performance of 6 ML Methods on Combined Data")
  
plt.xticks(ind+width/2,['kNN', 'LogReg', 'SVM', 'SGD', 'XGB', 'MLP'])
plt.legend( (bar1, bar2), ('F1 Score', 'Balanced Accuracy Score'), loc="best")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 3
ind = np.arange(N) 
width = 0.25

ens1 = [0.8344, 0.7469, 0.8312]
errors_1 = [0.0448, 0.0182, 0.0250]
bar1 = plt.bar(ind, ens1, width, color = 'r', yerr = errors_1)

ens2 = [0.8094, 0.7437, 0.8312]
errors_2 = [0.0498, 0.0378, 0.0249]
bar2 = plt.bar(ind+width, ens2, width, color = 'g', yerr = errors_2)

ens3 = [0.8344, 0.7625, 0.8187]
errors_3 = [0.0470, 0.0230, 0.0254]
bar3 = plt.bar(ind+width*2, ens3, width, color = 'b', yerr = errors_3)

plt.xlabel("Data Modality")
plt.ylabel('5-Fold Cross-Validation Accuracy')
plt.ylim(0.5, 1)
plt.yticks(np.arange(0.5, 1.01, step=0.05))
plt.title("Predictive Performances of Ensemble Methods")

plt.xticks(ind+width,['Genotype Data', 'CCI Data', 'Combined Data'])
plt.legend( (bar1, bar2, bar3), ('1st+2nd Best', '1st+3rd Best', '1st+2nd+3rd Best'), loc="best" )
plt.show()
